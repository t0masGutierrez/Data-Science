# %% [markdown]
# This notebook explores Christmas Tree Sales from 2010 to 2016

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Christmas Tree Sales.csv")
df.drop("index", axis = 1, inplace = True)
df
# Out:
#     Year Type of tree  Number of trees sold  Average Tree Price       Sales
# 0   2010    Real tree              27000000               36.12   975240000
# 1   2011    Real tree              30800000               34.87  1073996000
# 2   2012    Real tree              24500000               40.30   987350000
# 3   2013    Real tree              33020000               35.30  1165606000
# 4   2014    Real tree              26300000               39.50  1038850000
# 5   2015    Real tree              25900000               50.82  1316238000
# 6   2016    Real tree              27400000               74.70  2046780000
# 7   2010    Fake tree               8200000               64.61   529802000
# 8   2011    Fake tree               9500000               70.55   670225000
# 9   2012    Fake tree              10900000               72.50   790250000
# 10  2013    Fake tree              14700000               81.30  1195110000
# ...

# %%
# Scale #s
df["Number of trees sold"] /= 1000000
df["Sales"] /= 1000000000

# %%
# Summary Statistics
df.describe()
# Out:
#               Year  Number of trees sold  Average Tree Price      Sales
# count    14.000000             14.000000           14.000000  14.000000
# mean   2013.000000             20.230000           59.446429   1.098326
# std       2.075498              8.502216           20.110086   0.414836
# min    2010.000000              8.200000           34.870000   0.529802
# 25%    2011.250000             12.850000           39.700000   0.871447
# 50%    2013.000000             21.550000           64.105000   1.013100
# 75%    2014.750000             26.825000           72.012500   1.187734
# max    2016.000000             33.020000           98.700000   2.046780

# %%
# Number of trees sold by Type of tree
real = df["Type of tree"] == "Real tree"
real = df.loc[real, "Number of trees sold"].sum()

fake = df["Type of tree"] == "Fake tree"
fake = df.loc[fake, "Number of trees sold"].sum()

plt.pie([fake, real], labels = ["Fake trees", "Real trees"], autopct = "%.1f%%")
plt.title("Number of trees sold by Type of tree")
plt.show()

# %%
# Number of trees sold by Year and Type of tree
df.pivot_table(values = "Number of trees sold", index = "Year", columns = "Type of tree").plot.bar()
plt.ylabel("# of trees sold (Millions)")
plt.title("Number of trees sold by Year and Type of tree")
plt.show()

# %%
# Sales by Year and Type of tree
df.pivot_table(values = "Sales", index = "Year", columns = "Type of tree").plot(kind = "barh")
plt.xlabel("Sales (Billions)")
plt.ylabel("Year")
plt.title("Sales by Year and Type of tree")
plt.show()

# %%
# Average Tree Price by Year and Type of tree
df.pivot_table(values = "Average Tree Price", index = "Year", columns = "Type of tree").plot.line()
plt.ylabel("Average Tree Price")
plt.title("Average Tree Price by Year and Type of tree")
plt.show()
